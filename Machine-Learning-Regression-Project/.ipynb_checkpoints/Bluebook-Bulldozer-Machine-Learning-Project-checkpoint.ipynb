# %% [markdown]
# # 🚜 Predicting the Sale Price of Bulldozers using Machine Learning
#
# In this notebook, we're going to go through an example machine learning project with the goal of predicting the sale price of bulldozers.
#
# Since we're trying to predict a number, this kind of problem is known as a **regression problem**.
#
# The data and evaluation metric we'll be using (root mean square log error or RMSLE) is from the [Kaggle Bluebook for Bulldozers competition](https://www.kaggle.com/c/bluebook-for-bulldozers/overview).

# %% [markdown]
# ## 1. Problem definition
#
# > How well can we predict the future sale price of the bulldozer, given it's characteristics and previous examples of how much similar bulldozer has been sold for?

# %% [markdown]
# ## 2. Data
# The data is downloaded from [Kraggle bluebook bulldozer competition](https://www.kaggle.com/c/bluebook-for-bulldozers/data)
#
# There are 3 main data sets:
# 1. **Train.csv** is the training set, which contains data through the end of 2011.
# 2. **Valid.csv** is the validation set, which contains data from January 1, 2012 - April 30, 2012 You make predictions on this set throughout the majority of the competition. Your score on this set is used to create the public leaderboard.
# 3. **Test.csv** is the test set, which won't be released until the last week of the competition. It contains data from May 1, 2012 - November 2012

# %% [markdown]
# ## 3. Evaluation
# The evaluation metric for this competition is the RMSLE (root mean squared log error) between the actual and predicted auction price.
#
# To see how well our model is doing, we'll calculate the RMSLSE and then compare it with the with other's scores on [Kaggle leaderboard](https://www.kaggle.com/c/bluebook-for-bulldozers/leaderboard)

# %% [markdown]
# ## 4. Features
# Kaggle also provided a data dictonary, detailing all of the features of the data set. You can view this data dictionary on google sheets:https://docs.google.com/spreadsheets/d/1Pl9jrC50lfEdsgLe3mU7r1HdYvtu-RAUdAnQlfj4VQE/edit#gid=1393048805

# %% [markdown]
# ### Importing the data and preparing it for modelling

# %%
# Import data analysis tools
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn

# %%
# Importing data 
df=pd.read_csv(r"C:\Users\DELL\Desktop\git\TrainAndValid.csv",low_memory=False)

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246    66000.0     999089     3157         121           3.0      2004
# 1  1139248    57000.0     117657       77         121           3.0      1996
# 2  1139249    10000.0     434808     7009         121           3.0      2001
# 3  1139251    38500.0    1026470      332         121           3.0      2001
# 4  1139253    11000.0    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# 0                      68.0       Low  11/16/2006 0:00  ...
# 1                    4640.0       Low   3/26/2004 0:00  ...
# 2                    2838.0      High   2/26/2004 0:00  ...
# 3                    3486.0      High   5/19/2011 0:00  ...
# 4                     722.0    Medium   7/23/2009 0:00  ...
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   saledate                  412698 non-null  object
#  10  fiModelDesc               412698 non-null  object
#  11  fiBaseModel               412698 non-null  object
#  12  fiSecondaryDesc           271971 non-null  object
# ...

# %%
# As you can see our data has 52 features

# %%
# 2 main features of our data are saledate and Sale Price
# Let's plot a graph between them

fig, ax=plt.subplots(figsize=(10,6))
ax=plt.scatter(df.saledate[:1000],df.SalePrice[:1000]);

# %%
# In this graph we can't find what is happening so let's try again by parsing our date

# %%
df.saledate[:100] # datatype of our sale date feature is object
# Out:
# 0     11/16/2006 0:00
# 1      3/26/2004 0:00
# 2      2/26/2004 0:00
# 3      5/19/2011 0:00
# 4      7/23/2009 0:00
#            ...
# 95    12/15/2005 0:00
# 96     1/29/2004 0:00
# 97     9/18/2008 0:00
# 98     11/3/2005 0:00
# 99      6/1/2006 0:00
# Name: saledate, Length: 100, dtype: object

# %%
df.SalePrice.plot.hist();

# %%
# Find missing data
df.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# ...

# %% [markdown]
# ### Parsing Data
# When we work on the time series date, we want to enrich the time & and date component as much as possible
#
# We can do that by telling pandas which of our columns has dates in it using `parse_dates` parameter

# %%
# import data again but this time with  parse dates

df=pd.read_csv(r"C:\Users\DELL\Desktop\git\TrainAndValid.csv",parse_dates=["saledate"],low_memory=False)

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246    66000.0     999089     3157         121           3.0      2004
# 1  1139248    57000.0     117657       77         121           3.0      1996
# 2  1139249    10000.0     434808     7009         121           3.0      2001
# 3  1139251    38500.0    1026470      332         121           3.0      2001
# 4  1139253    11000.0    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand   saledate  ... Undercarriage_Pad_Width  \
# 0                      68.0       Low 2006-11-16  ...                     NaN
# 1                    4640.0       Low 2004-03-26  ...                     NaN
# 2                    2838.0      High 2004-02-26  ...                     NaN
# 3                    3486.0      High 2011-05-19  ...                     NaN
# 4                     722.0    Medium 2009-07-23  ...                     NaN
#
# ...

# %%
df.saledate.head(30) # Now datatype of our saledate feature is datetime
# Out:
# 0    2006-11-16
# 1    2004-03-26
# 2    2004-02-26
# 3    2011-05-19
# 4    2009-07-23
# 5    2008-12-18
# 6    2004-08-26
# 7    2005-11-17
# 8    2009-08-27
# 9    2007-08-09
# 10   2008-08-21
# 11   2006-08-24
# 12   2005-10-20
# 13   2006-01-26
# 14   2006-01-03
# 15   2006-11-16
# 16   2007-06-14
# 17   2010-01-28
# 18   2006-03-09
# 19   2005-11-17
# 20   2006-05-18
# 21   2006-10-19
# 22   2007-10-25
# 23   2006-10-19
# 24   2004-05-20
# 25   2006-03-09
# 26   2006-03-09
# 27   2007-02-22
# 28   2007-08-09
# 29   2006-06-01
# Name: saledate, dtype: datetime64[ns]

# %%
# now visualize our 2 main features which are saledate and SalesPrice

fig, ax= plt.subplots(figsize=(10,6))
ax=plt.scatter(df.saledate[:1000],df.SalePrice[:1000]);

# %%
# Now we can clearly differ our sales according to our choosen year

# %%
df.head().T
# Out:
#                                                                  0  \
# SalesID                                                    1139246
# SalePrice                                                    66000
# MachineID                                                   999089
# ModelID                                                       3157
# datasource                                                     121
# auctioneerID                                                     3
# YearMade                                                      2004
# MachineHoursCurrentMeter                                        68
# UsageBand                                                      Low
# saledate                                       2006-11-16 00:00:00
# fiModelDesc                                                   521D
# fiBaseModel                                                    521
# fiSecondaryDesc                                                  D
# ...

# %%
df.saledate.head(20)
# Out:
# 0    2006-11-16
# 1    2004-03-26
# 2    2004-02-26
# 3    2011-05-19
# 4    2009-07-23
# 5    2008-12-18
# 6    2004-08-26
# 7    2005-11-17
# 8    2009-08-27
# 9    2007-08-09
# 10   2008-08-21
# 11   2006-08-24
# 12   2005-10-20
# 13   2006-01-26
# 14   2006-01-03
# 15   2006-11-16
# 16   2007-06-14
# 17   2010-01-28
# 18   2006-03-09
# 19   2005-11-17
# Name: saledate, dtype: datetime64[ns]

# %%
# our sale date parameter is randomly arranged so to arrange it in ascending or descending order we will use sort_values 
# parameter or method

# %% [markdown]
# ### Sort DataFrame by Saledate
# When working with the time series data, it's a good idea to sort it by date

# %%
# Sort DataFrame by Date order

df.sort_values(by=["saledate"],inplace=True,ascending=True)

df.saledate.head(50)
# Out:
# 205615   1989-01-17
# 67974    1989-01-31
# 274835   1989-01-31
# 141296   1989-01-31
# 212552   1989-01-31
# 62755    1989-01-31
# 54653    1989-01-31
# 81383    1989-01-31
# 204924   1989-01-31
# 135376   1989-01-31
# 113390   1989-01-31
# 113394   1989-01-31
# 32138    1989-01-31
# 127610   1989-01-31
# 76171    1989-01-31
# 127000   1989-01-31
# 128130   1989-01-31
# 127626   1989-01-31
# 55455    1989-01-31
# 55454    1989-01-31
# 144032   1989-01-31
# 54438    1989-01-31
# 144952   1989-01-31
# 127300   1989-01-31
# 205752   1989-01-31
# 86971    1989-01-31
# 67034    1989-01-31
# 87602    1989-01-31
# 53101    1989-01-31
# 205784   1989-01-31
# 101796   1989-01-31
# 54181    1989-01-31
# 28757    1989-01-31
# 77792    1989-01-31
# 134119   1989-01-31
# 98346    1989-01-31
# 119369   1989-01-31
# 119449   1989-01-31
# 119199   1989-01-31
# 92833    1989-01-31
# 77650    1989-01-31
# 98567    1989-01-31
# 135284   1989-01-31
# 63155    1989-01-31
# 142669   1989-01-31
# ...

# %% [markdown]
# ### Make a copy of the original dataframe so when we manipulate the copy, we've still got our original data

# %%
# Make a copy
df_tmp=df.copy()

# %%
df_tmp.head()
# Out:
#         SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 205615  1646770     9500.0    1126363     8434         132          18.0
# 67974   1344379    70000.0    1374638     3819         132          99.0
# 274835  1821514    14000.0    1194089    10150         132          99.0
# 141296  1505138    50000.0    1473654     4139         132          99.0
# 212552  1671174    16000.0    1327630     8591         132          99.0
#
#         YearMade  MachineHoursCurrentMeter UsageBand   saledate  ...  \
# 205615      1974                       NaN       NaN 1989-01-17  ...
# 67974       1982                       NaN       NaN 1989-01-31  ...
# 274835      1980                       NaN       NaN 1989-01-31  ...
# 141296      1978                       NaN       NaN 1989-01-31  ...
# 212552      1980                       NaN       NaN 1989-01-31  ...
#
#        Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer  \
# ...

# %% [markdown]
# ### Add datetime parameters of sale date

# %%
df_tmp.saledate.dt.year.head(20)  # here dt represent Datetime module of pandas
# Out:
# 205615    1989
# 67974     1989
# 274835    1989
# 141296    1989
# 212552    1989
# 62755     1989
# 54653     1989
# 81383     1989
# 204924    1989
# 135376    1989
# 113390    1989
# 113394    1989
# 32138     1989
# 127610    1989
# 76171     1989
# 127000    1989
# 128130    1989
# 127626    1989
# 55455     1989
# 55454     1989
# Name: saledate, dtype: int64

# %%
# So let's add date time parameters into our data
df_tmp["saleYear"]=df_tmp.saledate.dt.year
df_tmp["saleMonth"]=df_tmp.saledate.dt.month
df_tmp["saleDay"]=df_tmp.saledate.dt.day
df_tmp["saleDayOfWeek"]=df_tmp.saledate.dt.dayofweek
df_tmp["saleDayofYear"]=df_tmp.saledate.dt.dayofyear

# Now that we have get all our datatime parameters we don't need datesale feature in our data
df_tmp.drop("saledate",axis=1,inplace=True)

# %%
df_tmp.head().T
# Out:
#                                                                      205615  \
# SalesID                                                             1646770
# SalePrice                                                              9500
# MachineID                                                           1126363
# ModelID                                                                8434
# datasource                                                              132
# auctioneerID                                                             18
# YearMade                                                               1974
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# fiModelDesc                                                            TD20
# fiBaseModel                                                            TD20
# ...

# %%
# Check the values of different columns
df_tmp.state.value_counts()
# Out:
# Florida           67320
# Texas             53110
# California        29761
# Washington        16222
# Georgia           14633
# Maryland          13322
# Mississippi       13240
# Ohio              12369
# Illinois          11540
# Colorado          11529
# New Jersey        11156
# North Carolina    10636
# Tennessee         10298
# Alabama           10292
# Pennsylvania      10234
# South Carolina     9951
# Arizona            9364
# New York           8639
# Connecticut        8276
# Minnesota          7885
# Missouri           7178
# Nevada             6932
# Louisiana          6627
# Kentucky           5351
# Maine              5096
# Indiana            4124
# Arkansas           3933
# New Mexico         3631
# Utah               3046
# Unspecified        2801
# Wisconsin          2745
# New Hampshire      2738
# Virginia           2353
# Idaho              2025
# Oregon             1911
# Michigan           1831
# Wyoming            1672
# Montana            1336
# ...

# %%
# Now let's build a model

# %% [markdown]
# ## 5. Modelling
# We've explored our dataset a little as well as enriched it with datetime attributes, now let's try to model
#
# You will be thinking why model so early?
#
# We know that the evaluation metric we're heading towards. We could spend more time doing exploratory data analysis (EDA), finding more about the data ourselves, but what we'll do instead is use machine learning to help us do EDA.

# %%
# let's build a machine learning model

from sklearn.ensemble import RandomForestRegressor

model=RandomForestRegressor(n_jobs=-1,random_state=42)

model.fit(df_tmp.drop("SalePrice",axis=1),df_tmp["SalePrice"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-f02d923e75cc> in <module>
#       5 model=RandomForestRegressor(n_jobs=-1,random_state=42)
#       6
# ----> 7 model.fit(df_tmp.drop("SalePrice",axis=1),df_tmp["SalePrice"])
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     302             )
#     303         X, y = self._validate_data(X, y, multi_output=True,
# --> 304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#     306             sample_weight = _check_sample_weight(sample_weight, X)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# ...

# %%
# That's right we can't build this model on our current data which has string components in it

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412698 entries, 205615 to 409203
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   object
#  9   fiModelDesc               412698 non-null  object
#  10  fiBaseModel               412698 non-null  object
#  11  fiSecondaryDesc           271971 non-null  object
#  12  fiModelSeries             58667 non-null   object
# ...

# %%
# We also have data which is missing
df.isna().sum()
# Out:
# SalesID                          0
# SalePrice                        0
# MachineID                        0
# ModelID                          0
# datasource                       0
# auctioneerID                 20136
# YearMade                         0
# MachineHoursCurrentMeter    265194
# UsageBand                   339028
# saledate                         0
# fiModelDesc                      0
# fiBaseModel                      0
# fiSecondaryDesc             140727
# fiModelSeries               354031
# fiModelDescriptor           337882
# ProductSize                 216605
# fiProductClassDesc               0
# state                            0
# ProductGroup                     0
# ProductGroupDesc                 0
# Drive_System                305611
# Enclosure                      334
# Forks                       214983
# Pad_Type                    331602
# Ride_Control                259970
# Stick                       331602
# Transmission                224691
# ...

# %% [markdown]
# ## Turning data into numbers
#
# **Converting String to Categories**
#
# One way we can convert our data into numbers is by converting them into pandas categories.
#
# To do this we can use the [pandas types API](https://pandas.pydata.org/pandas-docs/stable/reference/general_utility_functions.html#data-types-related-functionality) which allows us to interact and manipulate the types of data.

# %%
df_tmp.head().T
# Out:
#                                                                      205615  \
# SalesID                                                             1646770
# SalePrice                                                              9500
# MachineID                                                           1126363
# ModelID                                                                8434
# datasource                                                              132
# auctioneerID                                                             18
# YearMade                                                               1974
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# fiModelDesc                                                            TD20
# fiBaseModel                                                            TD20
# ...

# %%
pd.api.types.is_string_dtype(df_tmp["UsageBand"])  # This will tell us that a given label is String or not
# Out:
# True

# %%
# Find columns which contain strings

for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        print(label)
# Out:
# UsageBand
# fiModelDesc
# fiBaseModel
# fiSecondaryDesc
# fiModelSeries
# fiModelDescriptor
# ProductSize
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc
# Drive_System
# Enclosure
# Forks
# Pad_Type
# Ride_Control
# Stick
# Transmission
# Turbocharged
# Blade_Extension
# Blade_Width
# Enclosure_Type
# Engine_Horsepower
# Hydraulics
# Pushblock
# Ripper
# Scarifier
# Tip_Control
# Tire_Size
# Coupler
# Coupler_System
# Grouser_Tracks
# Hydraulics_Flow
# Track_Type
# Undercarriage_Pad_Width
# Stick_Length
# Thumb
# Pattern_Changer
# Grouser_Type
# Backhoe_Mounting
# Blade_Type
# Travel_Controls
# Differential_Type
# Steering_Controls

# %%
# Let's convert all the string values into categories values
for label, content in df_tmp.items():
    if pd.api.types.is_string_dtype(content):
        df_tmp[label]=content.astype("category").cat.as_ordered()

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 412698 entries, 0 to 412697
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   SalesID                   412698 non-null  int64
#  1   SalePrice                 412698 non-null  float64
#  2   MachineID                 412698 non-null  int64
#  3   ModelID                   412698 non-null  int64
#  4   datasource                412698 non-null  int64
#  5   auctioneerID              392562 non-null  float64
#  6   YearMade                  412698 non-null  int64
#  7   MachineHoursCurrentMeter  147504 non-null  float64
#  8   UsageBand                 73670 non-null   category
#  9   fiModelDesc               412698 non-null  category
#  10  fiBaseModel               412698 non-null  category
#  11  fiSecondaryDesc           271971 non-null  category
#  12  fiModelSeries             58667 non-null   category
# ...

# %%
df_tmp.state.cat.categories
# Out:
# Index(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Unspecified', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'Washington DC', 'West Virginia', 'Wisconsin',
#        'Wyoming'],
#       dtype='object')

# %%
df_tmp.state.cat.codes
# Out:
# 0         43
# 1          8
# 2          8
# 3          8
# 4          8
#           ..
# 412693     4
# 412694     4
# 412695     4
# 412696     4
# 412697     4
# Length: 412698, dtype: int8

# %% [markdown]
# ### Save preprocessed data

# %%
df_tmp.to_csv(r"C:\Users\DELL\Desktop\git\train-temporary.csv",index=False)

# %%
# Import preprocessed data

df_tmp=pd.read_csv(r"C:\Users\DELL\Desktop\git\train-temporary.csv",low_memory=False)

# %%
df_tmp.head().T
# Out:
#                                                                           0  \
# SalesID                                                             1646770
# SalePrice                                                              9500
# MachineID                                                           1126363
# ModelID                                                                8434
# datasource                                                              132
# auctioneerID                                                             18
# YearMade                                                               1974
# MachineHoursCurrentMeter                                                NaN
# UsageBand                                                               NaN
# fiModelDesc                                                            TD20
# fiBaseModel                                                            TD20
# ...

# %% [markdown]
# ## Filling missing values

# %% [markdown]
# ### Fill numerical missing values first

# %%
for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# SalesID
# SalePrice
# MachineID
# ModelID
# datasource
# auctioneerID
# YearMade
# MachineHoursCurrentMeter
# saleYear
# saleMonth
# saleDay
# saleDayOfWeek
# saleDayofYear

# %%
# Check for which numeric columns has null values

for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            print(label)
# Out:
# auctioneerID
# MachineHoursCurrentMeter

# %%
# Fill numeric rows with medians

for label, content in df_tmp.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            df_tmp[label + "_is_missing"]=pd.isnull(content)
            df_tmp[label]=content.fillna(content.median())

# %%
# we are using median instead of mode because it is more robust

# %%
# Check to see how many examples were missing
df_tmp.auctioneerID_is_missing.value_counts()
# Out:
# False    392562
# True      20136
# Name: auctioneerID_is_missing, dtype: int64

# %%
df_tmp.head().T
# Out:
#                                                                                      0  \
# SalesID                                                                        1646770
# SalePrice                                                                         9500
# MachineID                                                                      1126363
# ModelID                                                                           8434
# datasource                                                                         132
# auctioneerID                                                                        18
# YearMade                                                                          1974
# MachineHoursCurrentMeter                                                             0
# UsageBand                                                                          NaN
# fiModelDesc                                                                       TD20
# ...

# %% [markdown]
# ### Filling and turning categorical variables into numbers

# %%
# Check for columns which aren't numerical
df_tmp.isna().sum()
# Out:
# SalesID                                     0
# SalePrice                                   0
# MachineID                                   0
# ModelID                                     0
# datasource                                  0
# auctioneerID                                0
# YearMade                                    0
# MachineHoursCurrentMeter                    0
# UsageBand                              339028
# fiModelDesc                                 0
# fiBaseModel                                 0
# fiSecondaryDesc                        140727
# fiModelSeries                          354031
# fiModelDescriptor                      337882
# ProductSize                            216605
# fiProductClassDesc                          0
# state                                       0
# ProductGroup                                0
# ProductGroupDesc                            0
# Drive_System                           305611
# ...

# %%
for label, content in df_tmp.items():
    if not pd.api.types.is_numeric_dtype(content):
        print(label)
# Out:
# UsageBand
# fiModelDesc
# fiBaseModel
# fiSecondaryDesc
# fiModelSeries
# fiModelDescriptor
# ProductSize
# fiProductClassDesc
# state
# ProductGroup
# ProductGroupDesc
# Drive_System
# Enclosure
# Forks
# Pad_Type
# Ride_Control
# Stick
# Transmission
# Turbocharged
# Blade_Extension
# Blade_Width
# Enclosure_Type
# Engine_Horsepower
# Hydraulics
# Pushblock
# Ripper
# Scarifier
# Tip_Control
# Tire_Size
# Coupler
# Coupler_System
# Grouser_Tracks
# Hydraulics_Flow
# Track_Type
# Undercarriage_Pad_Width
# Stick_Length
# Thumb
# Pattern_Changer
# Grouser_Type
# Backhoe_Mounting
# Blade_Type
# Travel_Controls
# Differential_Type
# Steering_Controls

# %%
# Turning categorical variables into numbers and fill missing values

for label, content in df_tmp.items():
    if not pd.api.types.is_numeric_dtype(content):
        # Add a binary column to indiacte whether sample had missing value
        df_tmp[label + "_is_missing"]=pd.isnull(content)
        # Turn categories into numbers and add +1
        df_tmp[label]=pd.Categorical(content).codes +1

# %%
# In above cell we have add +1 because categorical codes fill null values with -1 so to overcome that we have add +1
pd.Categorical(df_tmp.UsageBand).codes
# Out:
# array([-1, -1, -1, ..., -1, -1, -1], dtype=int8)

# %%
# Now add +1 
pd.Categorical(df_tmp.UsageBand).codes +1
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int8)

# %%
df_tmp.isna().sum().head(30)
# Out:
# SalesID                     0
# SalePrice                   0
# MachineID                   0
# ModelID                     0
# datasource                  0
# auctioneerID                0
# YearMade                    0
# MachineHoursCurrentMeter    0
# UsageBand                   0
# fiModelDesc                 0
# fiBaseModel                 0
# fiSecondaryDesc             0
# fiModelSeries               0
# fiModelDescriptor           0
# ProductSize                 0
# fiProductClassDesc          0
# state                       0
# ProductGroup                0
# ProductGroupDesc            0
# Drive_System                0
# Enclosure                   0
# Forks                       0
# Pad_Type                    0
# Ride_Control                0
# Stick                       0
# Transmission                0
# Turbocharged                0
# Blade_Extension             0
# Blade_Width                 0
# Enclosure_Type              0
# dtype: int64

# %%
df_tmp.head().T
# Out:
#                                     0        1        2        3        4
# SalesID                       1646770  1344379  1821514  1505138  1671174
# SalePrice                        9500    70000    14000    50000    16000
# MachineID                     1126363  1374638  1194089  1473654  1327630
# ModelID                          8434     3819    10150     4139     8591
# datasource                        132      132      132      132      132
# ...                               ...      ...      ...      ...      ...
# Backhoe_Mounting_is_missing     False     True     True    False     True
# Blade_Type_is_missing           False     True     True    False     True
# Travel_Controls_is_missing      False     True     True    False     True
# Differential_Type_is_missing     True    False    False     True    False
# Steering_Controls_is_missing     True    False    False     True    False
#
# [103 rows x 5 columns]

# %%
# Now that we have fill of our missing values and turned all of our data to numeric datatype, Let's try to build a machine learning model
from sklearn.ensemble import RandomForestRegressor

model=RandomForestRegressor(n_jobs=-1,random_state=42)

# Fit the model
model.fit(df_tmp.drop("SalePrice",axis=1),df_tmp["SalePrice"])
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
# Check the score of the model on the same data 
model.score(df_tmp.drop("SalePrice",axis=1),df_tmp["SalePrice"])
# Out:
# 0.9875954615410482

# %%
# We get a score of 0.98 whattt! But above metric evaluation function is not reliable  because the score that we have get is made
# on the same data on which this model is trained

# %% [markdown]
# ### Splitting data into train/validation data sets

# %%
# Split data into training and validation sets
df_valid=df_tmp[df_tmp.saleYear==2012]
df_train=df_tmp[df_tmp.saleYear!=2012]

# Split data into X and y

X_train, y_train =df_train.drop("SalePrice",axis=1),df_train.SalePrice
X_valid, y_valid = df_valid.drop("SalePrice",axis=1), df_valid.SalePrice

# %% [markdown]
# ### Building an evaluation function

# %%
# Create evaluation metric function (the competition uses RMSLE)
from sklearn.metrics import mean_squared_log_error, mean_absolute_error, r2_score

def rmsle (y_test,y_preds):
    """
    Calculate root mean squared log error between predictions and true labels
    
    """
    
    return np.sqrt(mean_squared_log_error(y_test,y_preds))

# Create a function to evaluate our model on a few different levels

def show_scores(model):
    train_preds=model.predict(X_train)
    valid_preds=model.predict(X_valid)
    
    scores={"training MAE": mean_absolute_error(y_train, train_preds),
            "valid MAE": mean_absolute_error(y_valid, valid_preds),
            "training RMSLE": rmsle(y_train,train_preds),
            "valid RMSLE": rmsle(y_valid,valid_preds),
            "training R^2": r2_score(y_train,train_preds),
            "valid R^2": r2_score(y_valid,valid_preds)}
    return scores

# %%
# %%time
np.random.seed(42)

base_model=RandomForestRegressor(n_jobs=-1)

# Fit the model
base_model.fit(X_train,y_train)
# Out:
# Wall time: 7min 30s
# RandomForestRegressor(n_jobs=-1)

# %%
show_scores(base_model)
# Out:
# {'training MAE': 1577.837380916173,
#  'valid MAE': 6126.455659725222,
#  'training RMSLE': 0.08422689209652257,
#  'valid RMSLE': 0.25528283954079395,
#  'training R^2': 0.9875632871785163,
#  'valid R^2': 0.8723621310986868}

# %%
# So root mean squared log error for our base_model is 0.255282
# So let's improve our model to get better score
